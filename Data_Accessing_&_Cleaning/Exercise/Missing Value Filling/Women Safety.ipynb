# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; font-size: 72px; background-color: #5a189a; color: #ffffff; padding: 20px; border-radius: 20px; text-align: center; box-shadow: 0 4px 10px rgba(0, 0, 0, 0.2);">
#     About the Author 🧑‍💻
# </div>
#
# <div style="padding: 40px; max-width: 1000px; margin: 40px auto; background-color: #f9f9f9; border-radius: 15px; box-shadow: 0 4px 20px rgba(0, 0, 0, 0.1);">
#     <p style="font-size: 130%; line-height: 1.8; color: #444;">
#         Hello, Data Enthusiasts! 👋<br>
#         I'm <b style="color: #4682B4;">Rudra Prasad Bhuyan</b>, a passionate Data Analyst on a mission to master the art of transforming raw data into valuable insights that drive decision-making and foster business growth.
#     </p>
# </div>
#
# <div style="text-align: center; padding: 20px; margin-top: 30px;">
#     <p style="font-size: 120%; color: #444; line-height: 1.6;">
#         Let’s connect and create amazing things together! <br>
#         Reach out to me on
#         <a href="https://www.linkedin.com/in/rudra-prasad-bhuyan-44a388235/" target="_blank" style="color: #0073b1; font-weight: bold; text-decoration: none;">LinkedIn</a>,
#         check out my projects on
#         <a href="https://github.com/Rudra-G-23" target="_blank" style="color: #000; font-weight: bold; text-decoration: none;">GitHub</a>,
#         or email me at
#         <a href="mailto:rudraprasadbhuyan999@gmail.com" style="color: #D44638; font-weight: bold; text-decoration: none;">rudraprasadbhuyan999@gmail.com</a>. <br>
#         I'm always excited to explore new opportunities, collaborate, or discuss all things data! 🧑‍💻😄
#     </p>
# </div>

# %% [markdown]
# <div style="font-family: Arial, sans-serif; font-size: 69px; background-color: #5a189a; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px; text-align: center;">Table of Content </div>

# %% [markdown]
# # Table of Contents
# 1. [📊 Understand the Data](#understand-the-data)
# 2. [🧹 Data Cleaning](#data-cleaning)
#    1. [Best practice](#best-practice)
#    2. [Auto generate the graph for more fast & speed up Analysis](#best-practice)
#    3. [More details and fast Analysis use dtable libraries](#best-practice)
# 3. [🔍 Handle Missing Value](#analysis)
#    1. [Correlation  Matrix ](#31)
#    2. [Drop Rows with All NaN Values](#32)
#    3. [Drop Rows with Any NaN Values in Specific Columns](#33)
#    4. [Fill with Mean ](#34)
#    5. [Fill with Mode (Most Common Value)](#35)
#    6. [Fill with a Fixed Value:](#36)
#    7. [Forward Fill](#37)
#    8. [Fill with Interpolation](#38)
#    9. [Fill with Grouped Mean](#39)
#    10. [Fill with a Machine Learning Model](#310)
#    11. [Fill with Quantile-Based Value (e.g., 75th Percentile)](#311)
#    12. [Fill with Polynomial Interpolation](#312)
#    13. [Fill Using Data Transformation (e.g., Log Transformation)](#313)
#    14. [Fill with Cumulative Sum or Mean (for Ordered Data)](#314)
#    15. [K-Nearest Neighbors (KNN) Imputation](#315)
# 4. [📈 Conclusion](#conclusion)

# %% [markdown]
# <a id="understand-the-data"></a>
# <div style="background-color: #48cae4; border-radius: 15px; padding: 20px; text-align: left;">
#     <h1 style="margin: 0;">
#         <b>
#             <span style="color: Black;">Chapter One</span>
#             <span style="color: #ffffff;">|</span>
#             <span style="color: #FEEC37;"> Understand the Data 📊
#             </span>
#         </b>
#     </h1>
#     <br>
#     <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
#     </a>
# </div>

# %% [markdown]
# <a  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐ install all libraries
# <a>

# %%
'''
# !pip install numpy pandas matplotlib seaborn plotly missingno dtable autoviz skimpy
'''
# Out:
# '\n!pip install numpy pandas matplotlib seaborn plotly missingno dtable autoviz skimpy\n'

# %%
# import  Basic libraries 
import os
import datetime as dt

# import necessary data wrangling libraries 
import numpy as np  
import pandas as pd

# import fundamental libraries of viz
import matplotlib.pyplot as plt
import seaborn as sns

# import advance libraries for dynamic graphs
import plotly.express as px  
import plotly.graph_objects as go  
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

# import some extra libraries for fast and advance analysis 
import missingno as msno
from skimpy import skim
import dtable

# Remove warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
source = r'C:\Users\Rudra\Downloads\Python_Pandas_profiling\Women Safety\most-dangerous-countries-for-women-2024.csv'
df = pd.read_csv(source, encoding= 'unicode_escape')
df.sample(7)
# Out:
#          country  \
# 37        Canada
# 139      Albania
# 147       Latvia
# 10        Mexico
# 22        France
# 44    Mozambique
# 13   Philippines
#
#      MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  \
# 37                                               0.885
# 139                                              0.796
# 147                                              0.872
# 10                                               0.551
# 22                                               0.864
# 44                                               0.580
# 13                                               0.612
#
#      MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019  \
# 37                                              290.83
# 139                                                NaN
# 147                                                NaN
# 10                                              576.05
# 22                                              309.92
# ...

# %%
print("The size of the DataFrame:",df.size, '\n')
print('The Shape of the DataFrame', df.shape, '\n')
print("Available columns in the DataFrame:", df.columns)

# Calculate memory usage of the DataFrame
memory_size = df.memory_usage(deep=True).sum()
memory_size_mb = memory_size / (1024 ** 2)
print(f"\nEstimated memory size: {memory_size_mb:.2f} MB")
# Out:
# The size of the DataFrame: 1936
#
# The Shape of the DataFrame (176, 11)
#
# Available columns in the DataFrame: Index(['country',
#        'MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023',
#        'MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019',
#        'MostDangerousCountriesForWomen_WDIStreetSafety_2019',
#        'MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019',
#        'MostDangerousCountriesForWomen_WDINonPartnerViolence_2019',
#        'MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019',
#        'MostDangerousCountriesForWomen_WDILegalDiscrimination_2019',
#        'MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019',
#        'MostDangerousCountriesForWomen_WDIGenderInequality_2019',
#        'MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019'],
#       dtype='object')
#
# Estimated memory size: 0.02 MB

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   country                                                               176 non-null    object
#  1   MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  176 non-null    float64
#  2   MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019   50 non-null     float64
#  3   MostDangerousCountriesForWomen_WDIStreetSafety_2019                   50 non-null     float64
#  4   MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019            50 non-null     float64
#  5   MostDangerousCountriesForWomen_WDINonPartnerViolence_2019             50 non-null     float64
# ...

# %%
df.describe(include='all').T
# Out:
#                                                     count unique    top freq  \
# country                                               176    176  India    1
# MostDangerousCountriesForWomen_WomenPeaceAndSec...  176.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WomensDangerInde...   50.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WDIStreetSafety_...   50.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WDIIntentionalHo...   50.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WDINonPartnerVio...   50.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WDIIntimatePartn...   50.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WDILegalDiscrimi...   50.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WDIGlobalGenderG...   50.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WDIGenderInequal...   50.0    NaN    NaN  NaN
# MostDangerousCountriesForWomen_WDIAttitudesTowa...   50.0    NaN    NaN  NaN
#
# ...

# %% [markdown]
# <a id="data-cleaning"></a>
# <div style="background-color: #48cae4; border-radius: 15px; padding: 20px; text-align: left;">
#     <h1 style="margin: 0;">
#         <b>
#             <span style="color: Black;">Chapter Two</span>
#             <span style="color: #ffffff;">|</span>
#             <span style="color: #FEEC37;"> Data Cleaning 🧹
#             </span>
#         </b>
#     </h1>
#     <br>
#     <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
#     </a>
# </div>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# country                                                                   0
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023      0
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019     126
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                     126
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019              126
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019               126
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019          126
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019              126
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                  126
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                 126
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019          126
# dtype: int64

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# <a id="best-practice"></a>
# <div style="background-color: #48cae4; border-radius: 15px; padding: 20px; text-align: left;">
# <p style="color: Black;">
#    ⭐ <b>Best Practices <b>
#    <pre  style="color: Black; font-size: 20px;">
#    1.Before clean the data have a copy of Original Data.
#
#    </pre>
# </p>
#     <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
#     </a>
# </div>

# %%
dfc = df.copy()

# %%
dfc.rename(
    columns={
        'MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023': 'womens_peace_security_index_score_2023',
        'MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019': 'womens_danger_index_total_score_2019',
        'MostDangerousCountriesForWomen_WDIStreetSafety_2019': 'street_safety_2019',
        'MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019': 'intentional_homicide_2019',
        'MostDangerousCountriesForWomen_WDINonPartnerViolence_2019': 'non_partner_violence_2019',
        'MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019': 'intimate_partner_violence_2019',
        'MostDangerousCountriesForWomen_WDILegalDiscrimination_2019': 'legal_discrimination_2019',
        'MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019': 'global_gender_gap_2019',
        'MostDangerousCountriesForWomen_WDIGenderInequality_2019': 'gender_inequality_2019',
        'MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019': 'attitudes_toward_violence_2019'
    },
    inplace=True
)

# %%
msno.bar(dfc)
# Out:
# <Axes: >

# %%
dfc.isna().sum()
# Out:
# country                                     0
# womens_peace_security_index_score_2023      0
# womens_danger_index_total_score_2019      126
# street_safety_2019                        126
# intentional_homicide_2019                 126
# non_partner_violence_2019                 126
# intimate_partner_violence_2019            126
# legal_discrimination_2019                 126
# global_gender_gap_2019                    126
# gender_inequality_2019                    126
# attitudes_toward_violence_2019            126
# dtype: int64

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">⭐ More details and fast Analysis use dtable libraries </div>

# %%
# Launch D-Tale
'''
import dtable 
d = dtale.show(df)
print(d._url)  # Print the URL to manually open in the browser
'''
# Out:
# '\nimport dtable \nd = dtale.show(df)\nprint(d._url)  # Print the URL to manually open in the browser\n'

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">⭐Ato generate the graph for more fast & speed up Analysis </div>

# %%
'''
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()

df_auto = AV.AutoViz(
    filename='', 
    dfte=df, 
    depVar='', 
    chart_format='png', 
    verbose=2
)

'''
# Out:
# "\nfrom autoviz.AutoViz_Class import AutoViz_Class\n\nAV = AutoViz_Class()\n\ndf_auto = AV.AutoViz(\n    filename='', \n    dfte=df, \n    depVar='', \n    chart_format='png', \n    verbose=2\n)\n\n"

# %%
df[dfc.isnull()]
# Out:
#     country  \
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 171     NaN
# 172     NaN
# 173     NaN
# 174     NaN
# 175     NaN
#
#      MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
#
#      MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019  \
# ...

# %% [markdown]
# <a id="analysis"></a>
# <div style="background-color: #48cae4; border-radius: 15px; padding: 20px; text-align: left;">
#     <h1 style="margin: 0;">
#         <b>
#             <span style="color: Black;">Chapter Three</span>
#             <span style="color: #ffffff;">|</span>
#             <span style="color: #FEEC37;"> Handle Missing Value 🔍
#             </span>
#         </b>
#     </h1>
#     <br>
#     <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
#     </a>
# </div>

# %% [markdown]
# <a id="31"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:#000000; margin:0; font-size:100%; font-family:Arial, sans-serif; background-color:#48cae4; overflow:hidden;"><b>⚡ 1. Correlation Matrix</b>
#
# <a href="#table-of-contents" style="font-family:Arial, sans-serif; font-size:15px; background-color:#7b2cbf; color:#ffffff; padding:7px 15px; text-decoration:none; border-radius:15px; margin-left:10px;">
#     [Table of Content 📜⬆️]
# </a>
# </div>

# %%
numeric_df = dfc.select_dtypes(include=[float, int])
correlation_matrix = numeric_df.corr().T

fig = px.imshow(correlation_matrix, text_auto=True, aspect="auto",
                title='Correlation Matrix',
                color_continuous_scale='viridis')
fig.show()

# %%
# Get a skim summary of the dataset
skim(dfc)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 176    │ │ float64     │ 10    │                                                          │
# │ │ Number of columns │ 11     │ │ string      │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="32"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 2. Drop Rows with All NaN Values</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df1 = dfc.copy()

# %%
print("Before drop:", df1.shape)
df1.dropna( inplace=True)
print("After drop:", df1.shape)
# Out:
# Before drop: (176, 11)
# After drop: (50, 11)

# %%
msno.bar(df1)
# Out:
# <Axes: >

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="33"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 3. Drop Rows with Any NaN Values in Specific Columns</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df2 = dfc.copy()

# %%
df2.shape
# Out:
# (176, 11)

# %%
df2 = df2.dropna(subset=['womens_peace_security_index_score_2023', 
                       'womens_danger_index_total_score_2019',
                       'street_safety_2019'])

# %%
df2.shape
# Out:
# (50, 11)

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="34"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡4. Fill with Mean </b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df4 = dfc.copy()

# %%
df4['womens_danger_index_total_score_2019'].sample(7)
# Out:
# 0      541.25
# 39     542.75
# 38     291.23
# 7         NaN
# 36        NaN
# 118       NaN
# 129       NaN
# Name: womens_danger_index_total_score_2019, dtype: float64

# %%
df4['womens_danger_index_total_score_2019'].fillna(df4['womens_danger_index_total_score_2019'].mean(), inplace=True)

# %%
df4['womens_danger_index_total_score_2019'].sample(7)
# Out:
# 45     413.0116
# 114    413.0116
# 38     291.2300
# 83     551.3200
# 175    413.0116
# 107    380.8400
# 65     413.0116
# Name: womens_danger_index_total_score_2019, dtype: float64

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="35"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 5. Fill with Mode (Most Common Value):
#
# </b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df5= dfc.copy()

# %%
df5.loc[df5['intentional_homicide_2019'].isnull(), 'intentional_homicide_2019']
# Out:
# 4     NaN
# 5     NaN
# 7     NaN
# 9     NaN
# 14    NaN
#        ..
# 171   NaN
# 172   NaN
# 173   NaN
# 174   NaN
# 175   NaN
# Name: intentional_homicide_2019, Length: 126, dtype: float64

# %%
df5['intentional_homicide_2019'].fillna(df5['intentional_homicide_2019'].mode()[0], inplace=True)

# %%
df5.loc[df5['intentional_homicide_2019'].isnull(), 'intentional_homicide_2019']
# Out:
# Series([], Name: intentional_homicide_2019, dtype: float64)

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐
#
# </div>

# %% [markdown]
# <a id="36"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 6. Fill with a Fixed Value:</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df6 = dfc.copy()

# %%
df6[df6.isnull()['non_partner_violence_2019']]['non_partner_violence_2019']
# Out:
# 4     NaN
# 5     NaN
# 7     NaN
# 9     NaN
# 14    NaN
#        ..
# 171   NaN
# 172   NaN
# 173   NaN
# 174   NaN
# 175   NaN
# Name: non_partner_violence_2019, Length: 126, dtype: float64

# %%
df6['non_partner_violence_2019'].fillna(0, inplace=True)

# %%
df6[df6.isnull()['non_partner_violence_2019']]['non_partner_violence_2019']
# Out:
# Series([], Name: non_partner_violence_2019, dtype: float64)

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Useful if there’s a default or placeholder value that makes sense.
#
# </div>

# %% [markdown]
# <a id="37"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 7. Forward Fill</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df7 = dfc.copy()

# %%
df7.isnull()['intimate_partner_violence_2019'].sum()
# Out:
# 126

# %%
df7['intimate_partner_violence_2019'].fillna(method='ffill', inplace=True) #bfill -> backward filling

# %%
df7.isnull()['intimate_partner_violence_2019'].sum()
# Out:
# 0

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Fills missing values with the next valid entry in each column. or Fills missing values with the last valid entry in each column.
#
# </div>

# %% [markdown]
# <a id="38"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 8. Fill with Interpolation</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df8 = dfc.copy()

# %%
df8[df8['global_gender_gap_2019'].isnull()]['global_gender_gap_2019']
# Out:
# 4     NaN
# 5     NaN
# 7     NaN
# 9     NaN
# 14    NaN
#        ..
# 171   NaN
# 172   NaN
# 173   NaN
# 174   NaN
# 175   NaN
# Name: global_gender_gap_2019, Length: 126, dtype: float64

# %%
df8['global_gender_gap_2019'].interpolate(method='linear', inplace=True)

# %%
df8[df8['global_gender_gap_2019'].isnull()]['global_gender_gap_2019']
# Out:
# Series([], Name: global_gender_gap_2019, dtype: float64)

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Interpolates values, useful for continuous numerical columns.
#
# </div>

# %% [markdown]
# <a id="39"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡9.  Fill with Grouped Mean</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df9 = dfc.copy()

# %%
df9[['gender_inequality_2019', 'country']].isnull()
# Out:
#      gender_inequality_2019  country
# 0                     False    False
# 1                     False    False
# 2                     False    False
# 3                     False    False
# 4                      True    False
# ..                      ...      ...
# 171                    True    False
# 172                    True    False
# 173                    True    False
# 174                    True    False
# 175                    True    False
#
# [176 rows x 2 columns]

# %%
df9['gender_inequality_2019'] = df9.groupby('country')['gender_inequality_2019'].transform(lambda x: x.fillna(x.mean()))

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Fill NaN values with the mean of groups, such as based on another column like country (if it’s categorical).
#
# </div>

# %% [markdown]
# <a id="310"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 10. Fill with a Machine Learning Model</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Assuming df is your original DataFrame, create a copy for df10
df10 = dfc.copy()

# Separate rows with and without NaN in the target column
train_data = df10[df10['attitudes_toward_violence_2019'].notna()]
test_data = df10[df10['attitudes_toward_violence_2019'].isna()]

# Identify categorical columns to encode (e.g., 'country')
categorical_cols = ['country'] 

# Apply one-hot encoding to categorical columns in both train and test data
train_data_encoded = pd.get_dummies(train_data, columns=categorical_cols, drop_first=True)
test_data_encoded = pd.get_dummies(test_data, columns=categorical_cols, drop_first=True)

# Align train and test data columns (in case they have different categories)
train_X = train_data_encoded.drop(columns=['attitudes_toward_violence_2019'])
train_y = train_data_encoded['attitudes_toward_violence_2019']

# If the test data has different columns after encoding, align with train
test_X = test_data_encoded.reindex(columns=train_X.columns, fill_value=0)

# Fill NaN values in test_X if they exist
if test_X.isnull().values.any():
    test_X.fillna(0, inplace=True)  # Fill NaNs with 0 or choose another strategy

# Fit the model
model = LinearRegression()
model.fit(train_X, train_y)

# Predict missing values in the test_data and fill them in df10
df10.loc[df10['attitudes_toward_violence_2019'].isna(), 'attitudes_toward_violence_2019'] = model.predict(test_X)

# Optionally, check the updated DataFrame
print(df10[['attitudes_toward_violence_2019']])
# Out:
#      attitudes_toward_violence_2019
# 0                         74.000000
# 1                         80.000000
# 2                         21.000000
# 3                         51.000000
# 4                          1.950884
# ..                              ...
# 171                        2.250571
# 172                        2.118829
# 173                        2.182186
# 174                        2.270684
# 175                        2.168107
#
# [176 rows x 1 columns]

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Use a model to predict the missing values based on other columns.
#
# </div>

# %% [markdown]
# <a id="311"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 11. Fill with Quantile-Based Value (e.g., 75th Percentile)</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df11 = dfc.copy()

# %%
# Plot distribution before fill
plt.figure(figsize=(10, 6))
sns.histplot(df11['intentional_homicide_2019'], kde=True, bins=30)
plt.title("Distribution of Intentional Homicide 2019")
plt.xlabel("Intentional Homicide 2019")
plt.ylabel("Count")
plt.show()

# %%
df11['intentional_homicide_2019'].fillna(df11['intentional_homicide_2019'].quantile(0.75), inplace=True)

# %%
# Plot distribution after fill
plt.figure(figsize=(10, 6))
sns.histplot(df11['intentional_homicide_2019'], kde=True, bins=30)
plt.title("Distribution of Intentional Homicide 2019")
plt.xlabel("Intentional Homicide 2019")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Useful for skewed data, filling with a specific percentile value.
#
# </div>

# %% [markdown]
# <a id="312"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 12. Fill with Polynomial Interpolation</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df11['intimate_partner_violence_2019'].interpolate(method='polynomial', order=2, inplace=True)

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Polynomial interpolation can be useful if data has a non-linear trend.
#
# </div>

# %% [markdown]
# <a id="313"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 13. Fill Using Data Transformation (e.g., Log Transformation)</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
# Plot distribution Before fill
plt.figure(figsize=(10, 6))
sns.histplot(df11['legal_discrimination_2019'], kde=True, bins=30)
plt.title("Distribution of legal_discrimination_2019")
plt.xlabel("legal_discrimination_2019")
plt.ylabel("Count")
plt.show()

# %%
import numpy as np
df11['legal_discrimination_2019'] = np.log(df11['legal_discrimination_2019'] + 1)
df11['legal_discrimination_2019'].fillna(df11['legal_discrimination_2019'].mean(), inplace=True)
df11['legal_discrimination_2019'] = np.exp(df11['legal_discrimination_2019']) - 1

# %%
# Plot distribution Before fill
plt.figure(figsize=(10, 6))
sns.histplot(df11['legal_discrimination_2019'], kde=True, bins=30)
plt.title("Distribution of legal_discrimination_2019")
plt.xlabel("legal_discrimination_2019")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Apply a transformation, then fill, and revert the transformation.
#
# </div>

# %% [markdown]
# <a id="314"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 14. Fill with Cumulative Sum or Mean (for Ordered Data)</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df10['global_gender_gap_2019'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df10['global_gender_gap_2019'] = df10['global_gender_gap_2019'].fillna(df10['global_gender_gap_2019'].expanding().mean()).plot(kind='kde')

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐Use cumulative statistics if the data has an order.
#
# </div>

# %% [markdown]
# <a id="315"></a>
# ### <div style="text-align:left; border-radius:15px; padding:20px; color:Black; margin:0; font-size:100%; font-family:Arial; background-color:#48cae4; overflow:hidden"><b>⚡ 15. K-Nearest Neighbors (KNN) Imputation</b>
# <a href="#table-of-contents" style="font-family: Arial, sans-serif; font-size: 15px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
#         [Table of Content 📜⬆️]
# </a>
# </div>

# %%
df10['gender_inequality_2019'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df10['gender_inequality_2019'].plot(kind='hist')
#  ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')
# Out:
# <Axes: ylabel='Frequency'>

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df10[['gender_inequality_2019']] = imputer.fit_transform(df10[['gender_inequality_2019']])

# %%
df10['gender_inequality_2019'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df10['gender_inequality_2019'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# <div  style="font-family: Arial, sans-serif; font-size: 20px; background-color: #7b2cbf; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 15px;">
# ⭐ Uses KNN to predict missing values based on neighboring points.
#
# </div>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; font-size: 72px; background-color: #5a189a; color: #ffffff; padding: 20px; border-radius: 20px; text-align: center; box-shadow: 0 4px 10px rgba(0, 0, 0, 0.2);">
#    Thank you
# </div
