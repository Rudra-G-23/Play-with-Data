# %% [markdown]
# Hello Data points 😄
#
# # My Class Notes
#
# **By Rudra**
#
# > Hi everyone, these are my class notes from one of my favorite teachers, Nitesh sir.
#
#
#
# Class- [Link](#https://www.youtube.com/live/1z5-O7-5AXk?si=sNzNJbgThpzOkPg9)

# %% [markdown]
# # 1. Python Output

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('salman khan')
# Out:
# salman khan

# %%
print(7)
# Out:
# 7

# %%
print(7.7)

# %%
print(True)
# Out:
# True

# %%
print('India', 7, 7.7, True)
# Out:
# India 7 7.7 True

# %%
print('India', 7, 7.7, True, sep='|')
# Out:
# India|7|7.7|True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello', end='---')
print('world')
# Out:
# hello---world

# %% [markdown]
# # 2. Data Types

# %%
# integer

print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal / float

print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean

print(True)
print(False)
# Out:
# True
# False

# %%
# Text / String

print('Hello World')
# Out:
# Hello World

# %%
# complex

print(5+6j)
# Out:
# (5+6j)

# %%
# List

print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple

print( (1, 2, 3, 4, 5) )
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets

print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary

print({'name':'Rudra', 'gender':'Male', 'weight':65})
# Out:
# {'name': 'Rudra', 'gender': 'Male', 'weight': 65}

# %%
# tyoe function

type([1,2,3])
# Out:
# list

# %% [markdown]
# # 3. Variables
# - They are container for future

# %%
# c/ c+
name = 'Rudra'
print(name)

a = 5
b = 6

print(a + b)
# Out:
# Rudra
# 11

# %%
# Dynamic Typing

a = 5
# var can change through out the code

# Static Binding
a = 10

# %%
a = 5
b = 2
c = 5

print(a + b + c)
# Out:
# 12

# %%
a = b = c = 5
print(a + b + c)
print(a, b, c)
# Out:
# 15

# %% [markdown]
# # comments

# %%
# single line by line code write
/*
multi line comment
But in industry single line comment is used
*/

# %% [markdown]
# # 4. Keywords & Identifiiers

# %%
# compilation - it is language to convert your word into binary
# complie - all in dierectly
# interpiter - one by one

# %%
# prompt: write all keywords in here

import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Identifiers

# you can't start with a digit
namw1 = 'Rudra'
print(namw1)

# you can use only underscore
name2 = 'Rudra_Prasad_bhuyan'
print(name2)

# you can't use special symbols
# case sensitive

# %% [markdown]
# # 5. User Heading

# %%
input('Enter Your Email :')
# Out:
# Enter Your Email :rudraprasadbhuyan000@gmail.com
# 'rudraprasadbhuyan000@gmail.com'

# %%
# Take input from user and store them in a variable
fnum = input('enter first number :')
snum = input('enter second number :')

# add tow variables
result = int(fnum) + int(snum)

# print the result
print(result)

print(type(fnum))
# it doesnot change the original data type
# Out:
# enter first number :100
# enter second number :25
# 125
# <class 'str'>

# %% [markdown]
# #6. Type conversion

# %% [markdown]
# - Implicit Type Conversion: This is done automatically by Python.
#
# - Explicit Type Conversion: This is done by the programmer using predefined functions

# %%
# implicit
print(5+5.6)
print(type(5), type(5.6))

print(4 + '4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6b85ab1e2cf5> in <cell line: 5>()
#       3 print(type(5), type(5.6))
#       4
# ----> 5 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int
print(type(int('4')))

# float -> int
print(int(4.5))

# int -> float
print(float(4))
# Out:
# <class 'int'>
# 4
# 4.0

# %% [markdown]
# # 7. Literals

# %%
# integer
a = 0b1010 # Binary Literals
b = 100 # Decimal Literal
c = 0o310 # Octal Literal
d = 0x12c # Hexadecimal Literal

#float Literal
float_1 = 10.5
float_2 = 1.5e2 #1.5 * 1o^2  --> Very big
float_3 = 1.5e-3 #1.5 * 1o^-3 -->Very small

# complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2, float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
string = 'This is Python'
strings = "This is Python"

char = 'Python'
multieple_line = '''Hello Data Points'''
raw_str = r"raw \n string"

unicode = u"\U0001F642\u2764\U0001F606"

print(string)
print(strings)
print(char)
print(multieple_line)
print(raw_str)
print(unicode)
# Out:
# This is Python
# This is Python
# Python
# Hello Data Points
# raw \n string
# 🙂❤😆

# %%
# Unicode characters

smile = "\U0001F642"  # 🙂
laugh = "\U0001F602"  # 😂
laughing = "\U0001F606"  # 😆
clapping = "\U0001F44F"  # 👏
dancing = "\U0001F483"  # 💃
heart = "\u2764"  # ❤️

print("Smile:", smile)
print("Laugh:", laugh)
print("Laughing:", laughing)
print("Clapping:", clapping)
print("Dancing:", dancing)
print("Heart:", heart)
# Out:
# Smile: 🙂
# Laugh: 😂
# Laughing: 😆
# Clapping: 👏
# Dancing: 💃
# Heart: ❤

# %%
# internal python think True = 1 & False = 0

a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
R = None
print(R)

a = 5
b = 6
print('Program exe')
# Out:
# None
# Program exe

# %% [markdown]
#  Opraters and if-else in next notebook
